# %%
REPO_PATH = 'C:\\JosephYu\\serverless-python-demo'

import os

def print_directory_contents(path, indent_level=0):
    # Create the indentation string
    indent = ' ' * 4 * indent_level
    # Determine the type of current path (file or folder)
    if os.path.isdir(path):
        print(f'{indent}[L-{indent_level}:📂FOLDER]{os.path.basename(path)}/')
        # Recursively call the function for each item in the directory
        for item in sorted(os.listdir(path)):
            print_directory_contents(os.path.join(path, item), indent_level + 1)
    else:
        print(f'{indent}[L-{indent_level}:📑file]{os.path.basename(path)}')

# Replace 'your_repo_path' with the path to your local repository
print_directory_contents(REPO_PATH)
# Out:
# [L-0:📂FOLDER]serverless-python-demo/
#     [L-1:📑file].coveragerc
#     [L-1:📂FOLDER].git/
#         [L-2:📑file]COMMIT_EDITMSG
#         [L-2:📑file]FETCH_HEAD
#         [L-2:📑file]HEAD
#         [L-2:📑file]ORIG_HEAD
#         [L-2:📑file]config
#         [L-2:📑file]description
#         [L-2:📂FOLDER]hooks/
#             [L-3:📑file]applypatch-msg.sample
#             [L-3:📑file]commit-msg.sample
#             [L-3:📑file]fsmonitor-watchman.sample
#             [L-3:📑file]post-update.sample
#             [L-3:📑file]pre-applypatch.sample
#             [L-3:📑file]pre-commit.sample
#             [L-3:📑file]pre-merge-commit.sample
#             [L-3:📑file]pre-push.sample
#             [L-3:📑file]pre-rebase.sample
#             [L-3:📑file]pre-receive.sample
#             [L-3:📑file]prepare-commit-msg.sample
#             [L-3:📑file]push-to-checkout.sample
#             [L-3:📑file]sendemail-validate.sample
#             [L-3:📑file]update.sample
#         [L-2:📑file]index
# ...
